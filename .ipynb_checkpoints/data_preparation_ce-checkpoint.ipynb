# %%
import numpy as nm #importing required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("CE_SE_2021.csv") #importing dataset

# %%
df.head() #showing first 5 rows in the dataset
# Out:
#    DISCRETE MATHEMATICS  FUND. OF DATA STRUCTURES  \
# 0                    27                        24
# 1                    30                        30
# 2                    24                        27
# 3                    27                        27
# 4                    30                        30
#
#    OBJECT ORIENTED PROGRAMMING  COMPUTER GRAPHICS  \
# 0                           21                 27
# 1                           30                 30
# 2                           30                 27
# 3                           30                 27
# 4                           30                 30
#
#    DIGITAL ELEC. & LOGIC DESIGN  DATA STUCTURES LABORATORY  \
# 0                            30                         16
# 1                            30                         18
# 2                            30                         18
# 3                            30                         14
# ...

# %%
df.head(20) #showing first 20 rows in the dataset
# Out:
#     DISCRETE MATHEMATICS  FUND. OF DATA STRUCTURES  \
# 0                     27                        24
# 1                     30                        30
# 2                     24                        27
# 3                     27                        27
# 4                     30                        30
# 5                     30                        30
# 6                     30                        30
# 7                     27                        24
# 8                     30                        27
# 9                     30                        30
# 10                    24                        30
# 11                    30                        30
# 12                    30                        30
# 13                    30                        30
# 14                    30                        30
# 15                    30                        30
# 16                    30                        30
# ...

# %%
df.shape #printing number of rows and columns
# Out:
# (333, 26)

# %%
df.isnull().sum() #printing the number of null values in each column
# Out:
# DISCRETE MATHEMATICS               0
# FUND. OF DATA STRUCTURES           0
# OBJECT ORIENTED PROGRAMMING        0
# COMPUTER GRAPHICS                  0
# DIGITAL ELEC. & LOGIC DESIGN       0
# DATA STUCTURES LABORATORY          0
# OOP & COMP. GRAPHICS LAB.          0
# DIGITAL ELEC. LABORATORY           0
# BUSINESS COMMUNICATION SKILLS      0
# HUMANITY & SOCIAL SCIENCE          0
# AUDIT COURSE                     333
# ENGINEERING MATHEMATICS III       10
# ENGINEERING MATHEMATICS III.1      0
# DATA STRUCTURES & ALGO.           12
# SOFTWARE ENGINEERING               9
# MICROPROCESSOR                    11
# PRINCIPLES OF PROG. LANG.          8
# DATA STRUCTURES & ALGO. LAB.      19
# MICROPROCESSOR LABORATORY          8
# PROJECT BASED LEARNING II          0
# CODE OF CONDUCT                    0
# AUDIT COURSE.1                   333
# SEM_3_SGPA                         0
# SEM_4_SGPA                         0
# TOTAL_CREDITS_EARNED               0
# ...

# %%
print("Total missing values: ", df.isnull().sum().sum()) #printing the total number of null values
# Out:
# Total missing values:  743

# %%
df.info() #printing the details of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DISCRETE MATHEMATICS           333 non-null    int64
#  1   FUND. OF DATA STRUCTURES       333 non-null    int64
#  2   OBJECT ORIENTED PROGRAMMING    333 non-null    int64
#  3   COMPUTER GRAPHICS              333 non-null    int64
#  4   DIGITAL ELEC. & LOGIC DESIGN   333 non-null    int64
#  5   DATA STUCTURES LABORATORY      333 non-null    int64
#  6   OOP & COMP. GRAPHICS LAB.      333 non-null    int64
#  7   DIGITAL ELEC. LABORATORY       333 non-null    int64
#  8   BUSINESS COMMUNICATION SKILLS  333 non-null    int64
#  9   HUMANITY & SOCIAL SCIENCE      333 non-null    int64
#  10  AUDIT COURSE                   0 non-null      float64
#  11  ENGINEERING MATHEMATICS III    323 non-null    float64
# ...

# %%
df.dtypes #printing the data types of each column
# Out:
# DISCRETE MATHEMATICS               int64
# FUND. OF DATA STRUCTURES           int64
# OBJECT ORIENTED PROGRAMMING        int64
# COMPUTER GRAPHICS                  int64
# DIGITAL ELEC. & LOGIC DESIGN       int64
# DATA STUCTURES LABORATORY          int64
# OOP & COMP. GRAPHICS LAB.          int64
# DIGITAL ELEC. LABORATORY           int64
# BUSINESS COMMUNICATION SKILLS      int64
# HUMANITY & SOCIAL SCIENCE          int64
# AUDIT COURSE                     float64
# ENGINEERING MATHEMATICS III      float64
# ENGINEERING MATHEMATICS III.1      int64
# DATA STRUCTURES & ALGO.          float64
# SOFTWARE ENGINEERING             float64
# MICROPROCESSOR                   float64
# PRINCIPLES OF PROG. LANG.        float64
# DATA STRUCTURES & ALGO. LAB.     float64
# MICROPROCESSOR LABORATORY        float64
# PROJECT BASED LEARNING II          int64
# CODE OF CONDUCT                    int64
# AUDIT COURSE.1                   float64
# SEM_3_SGPA                       float64
# ...

# %%
mean_sgpa_sem3 = df['SEM_3_SGPA'].mean() #calculating the mean of SEM 3 SGPA
mean_sgpa_sem3
# Out:
# 9.436123123123124

# %%
mean_sgpa_sem4 = df['SEM_4_SGPA'].mean() #calculating the mean of SEM 3 SGPA
mean_sgpa_sem4
# Out:
# 7.408681681681683

# %%
df.columns #printing all the columns in the dataset
# Out:
# Index(['DISCRETE MATHEMATICS', 'FUND. OF DATA STRUCTURES',
#        'OBJECT ORIENTED PROGRAMMING', 'COMPUTER GRAPHICS',
#        'DIGITAL ELEC. & LOGIC DESIGN', 'DATA STUCTURES LABORATORY',
#        'OOP & COMP. GRAPHICS LAB.', 'DIGITAL ELEC. LABORATORY',
#        'BUSINESS COMMUNICATION SKILLS', 'HUMANITY & SOCIAL SCIENCE',
#        'AUDIT COURSE', 'ENGINEERING MATHEMATICS III',
#        'ENGINEERING MATHEMATICS III.1', 'DATA STRUCTURES & ALGO.',
#        'SOFTWARE ENGINEERING', 'MICROPROCESSOR', 'PRINCIPLES OF PROG. LANG.',
#        'DATA STRUCTURES & ALGO. LAB.', 'MICROPROCESSOR LABORATORY',
#        'PROJECT BASED LEARNING II', 'CODE OF CONDUCT', 'AUDIT COURSE.1',
#        'SEM_3_SGPA', 'SEM_4_SGPA', 'TOTAL_CREDITS_EARNED', 'CGPA'],
#       dtype='object')

# %%
df2 = df.filter(['SEM_3_SGPA', 'SEM_4_SGPA', 'CGPA']) #showing only the required columns
df2
# Out:
#      SEM_3_SGPA  SEM_4_SGPA  CGPA
# 0         8.364       3.000    --
# 1         9.591       8.727  9.16
# 2         8.818       7.318  8.07
# 3         9.091       8.273  8.68
# 4         9.727       6.364  8.05
# ..          ...         ...   ...
# 328       9.273       6.409  7.84
# 329       9.045       6.682  7.86
# 330       9.545       8.227  8.89
# 331       9.091       7.955  8.52
# 332      10.000       8.091  9.05
#
# [333 rows x 3 columns]

# %%
mean = df['SEM_3_SGPA'].mean() #replacing the null values with the mean value
df['SEM_3_SGPA'].fillna(value = mean, inplace = True)

# %%
mean = df['SEM_4_SGPA'].mean() #replacing the null values with the mean value
df['SEM_4_SGPA'].fillna(value = mean, inplace = True)

# %%
mode = df['ENGINEERING MATHEMATICS III'].mode().iloc[0] #replacing the null values with the mode
df['ENGINEERING MATHEMATICS III'].fillna(value = mode, inplace = True)

# %%
mode = df['DATA STRUCTURES & ALGO.'].mode().iloc[0] #replacing the null values with the mode
df['DATA STRUCTURES & ALGO.'].fillna(value = mode, inplace = True)

# %%
mode = df['SOFTWARE ENGINEERING'].mode().iloc[0] #replacing the null values with the mode
df['SOFTWARE ENGINEERING'].fillna(value = mode, inplace = True)

# %%
mode = df['MICROPROCESSOR'].mode().iloc[0] #replacing the null values with the mode
df['MICROPROCESSOR'].fillna(value = mode, inplace = True)

# %%
mode = df['DATA STRUCTURES & ALGO. LAB.'].mode().iloc[0] #replacing the null values with the mode
df['DATA STRUCTURES & ALGO. LAB.'].fillna(value = mode, inplace = True)

# %%
mode = df['PRINCIPLES OF PROG. LANG.'].mode().iloc[0] #replacing the null values with the mode
df['PRINCIPLES OF PROG. LANG.'].fillna(value = mode, inplace = True)

# %%
mode = df['MICROPROCESSOR LABORATORY'].mode().iloc[0] #replacing the null values with the mode
df['MICROPROCESSOR LABORATORY'].fillna(value = mode, inplace = True)

# %%
df.isnull().sum() #after replacing null values, final dataset showing number of null values
# Out:
# DISCRETE MATHEMATICS               0
# FUND. OF DATA STRUCTURES           0
# OBJECT ORIENTED PROGRAMMING        0
# COMPUTER GRAPHICS                  0
# DIGITAL ELEC. & LOGIC DESIGN       0
# DATA STUCTURES LABORATORY          0
# OOP & COMP. GRAPHICS LAB.          0
# DIGITAL ELEC. LABORATORY           0
# BUSINESS COMMUNICATION SKILLS      0
# HUMANITY & SOCIAL SCIENCE          0
# AUDIT COURSE                     333
# ENGINEERING MATHEMATICS III        0
# ENGINEERING MATHEMATICS III.1      0
# DATA STRUCTURES & ALGO.            0
# SOFTWARE ENGINEERING               0
# MICROPROCESSOR                     0
# PRINCIPLES OF PROG. LANG.          0
# DATA STRUCTURES & ALGO. LAB.       0
# MICROPROCESSOR LABORATORY          0
# PROJECT BASED LEARNING II          0
# CODE OF CONDUCT                    0
# AUDIT COURSE.1                   333
# SEM_3_SGPA                         0
# SEM_4_SGPA                         0
# TOTAL_CREDITS_EARNED               0
# ...
